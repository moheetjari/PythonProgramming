# %% [markdown]
# <a href="https://colab.research.google.com/github/moheetjari/PythonProgramming/blob/main/BostonHouseMultipleLinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split 
import math

# %%
data = pd.read_csv('/content/BostonHousing.csv')
#replaced zeros
zeros_not_accepeted = ['zn','chas']
for column in zeros_not_accepeted:
  data[column]=data[column].replace(0,np.NaN)
  mean=int(data[column].mean(skipna=True))
  data[column]=data[column].replace(np.NaN,mean)

# %%
data.head()
# Out:
#       crim    zn  indus  chas    nox  ...  tax  ptratio       b  lstat  medv
# 0  0.00632  18.0   2.31   1.0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731  42.0   7.07   1.0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729  42.0   7.07   1.0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237  42.0   2.18   1.0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905  42.0   2.18   1.0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
X = data[['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat']]
y = data[['medv']]

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Co-efficient
m = regr.coef_
m
# Out:
# array([[-1.09160589e-01,  4.55306617e-02,  2.37661483e-02,
#          2.18797203e-13, -1.77774156e+01,  3.99092452e+00,
#          1.46785878e-03, -1.25985376e+00,  3.40931346e-01,
#         -1.34169735e-02, -1.13285436e+00,  1.00748860e-02,
#         -5.23989426e-01]])

# %%
#intercept
c = regr.intercept_
c
# Out:
# array([36.36506813])

# %%
regr.predict(X)
# Out:
# array([[29.28390201],
#        [26.06812072],
#        [31.72764253],
#        [29.83698128],
#        [29.2104903 ],
#        [26.39475243],
#        [22.66704626],
#        [19.34330009],
#        [11.26478281],
#        [18.81826316],
#        [18.92555919],
#        [21.40944594],
#        [20.50306309],
#        [19.86512246],
#        [19.5755908 ],
#        [19.53889502],
#        [20.75747454],
#        [17.14649993],
#        [16.1049894 ],
#        [18.48528909],
#        [12.59297966],
#        [17.85813435],
#        [16.05298746],
#        [13.9981509 ],
#        [15.94874887],
#        [13.53427574],
#        [15.7578859 ],
#        [14.94204334],
#        [19.92569243],
#        [21.22834255],
#        [11.62972288],
#        [18.29593354],
#        [ 8.87304226],
#        [14.35536334],
#        [13.76314263],
#        [24.22286556],
#        [22.71856386],
#        [23.604484  ],
#        [23.40237983],
#        [30.41855309],
#        [33.34723646],
# ...

# %%
from sklearn.linear_model import  LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(data[['zn']],y)
plt.xlabel('zn')
plt.ylabel('medv')
plt.scatter(data[['zn']],y)
plt.plot(data[['zn']], lin_reg.predict(data[['zn']]), color='black')
plt.title('Linear Regression line')
plt.show()
